# %%
#DATA EXPLORATION
# IMPORTING LIBRARIES FOR DATA ANALYSIS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#IGNORE HARMLESS WARNINGS
import warnings
warnings.filterwarnings("ignore")
#SET TO DISPALY ALL COLUMNS IN THE DATA SET
pd.set_option("display.max_columns",None)

# %%
#LOADING THE DATA SET 
stdata=pd.read_csv(r'C:\Users\R Sobha Supriya\Downloads\SampleSuperstore.csv',header=0)
#COPY THE BACK-UP FILES
stdata_bk=stdata.copy()
#DISPLAY THE DATA
stdata
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#DISPLAY THE DATA SET INFORMATION
stdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#DISPLAY THE TOTAL SHAPE THAT INCLUDES NO OF RECORDS AND ATTRIBUTES OF DATA SET
stdata.shape
# Out:
# (9994, 13)

# %%
#TO DISPLAY MISSING VALUES IN DATA SET
stdata.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#4
#IDENTIFY DUPLICATES IN DATA SET
stdata_dup=stdata[stdata.duplicated(keep='last')]
#DISPLAY DUPLICATE RECORDS
stdata_dup
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# 3412  Standard Class    Corporate  United States  San Francisco    California
# ...

# %%
#TO IDENTIFY DUPLICATES IN DATA SET
stdata.duplicated().any()
# Out:
# True

# %%
#5
#remove the identified duplicate records duplicates
stdata=stdata.drop_duplicates()
#display the shape of dataset
stdata.shape
# Out:
# (9977, 13)

# %%
#6
#resetting row index
stdata=stdata.reset_index(drop='True')
#take another backup copy file to backup file after deletion of duplicate records
stdata_bk2=stdata.copy()

# %%
#TO IDENTIFY DUPLICATES IN DATA SET
stdata.duplicated().any()
# Out:
# False

# %%
stdata.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
del stdata['Country']

# %%
del stdata['State']

# %%
del stdata['Postal Code']

# %%
del stdata['Region']

# %%
del stdata['Ship Mode']

# %%
stdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9977 entries, 0 to 9976
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Segment       9977 non-null   object
#  1   City          9977 non-null   object
#  2   Category      9977 non-null   object
#  3   Sub-Category  9977 non-null   object
#  4   Sales         9977 non-null   float64
#  5   Quantity      9977 non-null   int64
#  6   Discount      9977 non-null   float64
#  7   Profit        9977 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 623.7+ KB

# %%
import pandas as pd

# Load your data into a pandas DataFrame (replace 'data.csv' with your file)
# df = pd.read_csv('data.csv')

# Specify the column containing the numerical data you want to analyze (e.g., "Sales Amount ($)")
numerical_column = "Profit"

# Calculate the interquartile range (IQR)
Q1 = stdata[numerical_column].quantile(0.25)
Q3 = stdata[numerical_column].quantile(0.75)
IQR = Q3 - Q1

# Define the upper and lower bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = stdata[(stdata[numerical_column] < lower_bound) | (stdata[numerical_column] > upper_bound)]

# Print the outliers
print("Outliers:")
print(outliers)
# Out:
# Outliers:
#           Segment             City         Category Sub-Category      Sales  \
# 1        Consumer        Henderson        Furniture       Chairs   731.9400
# 3        Consumer  Fort Lauderdale        Furniture       Tables   957.5775
# 7        Consumer      Los Angeles       Technology       Phones   907.1520
# 10       Consumer      Los Angeles        Furniture       Tables  1706.1840
# 13       Consumer          Seattle  Office Supplies      Binders   407.9760
# ...           ...              ...              ...          ...        ...
# 9940  Home Office     New Rochelle  Office Supplies        Paper   223.9200
# 9945  Home Office          Houston        Furniture    Bookcases   383.4656
# 9951     Consumer       Plainfield  Office Supplies      Binders   735.9800
# 9962  Home Office      Los Angeles  Office Supplies      Binders   437.4720
# 9976     Consumer      Westminster  Office Supplies   Appliances   243.1600
#
#       Quantity  Discount    Profit
# ...

# %%
import pandas as pd

# Load your data into a pandas DataFrame (replace 'data.csv' with your file)
# df = pd.read_csv('data.csv')

# Specify the column containing the numerical data you want to analyze (e.g., "Profit")
numerical_column = "Profit"

# Calculate the interquartile range (IQR)
Q1 = stdata[numerical_column].quantile(0.25)
Q3 = stdata[numerical_column].quantile(0.75)
IQR = Q3 - Q1

# Define the upper and lower bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_no_outliers = stdata[(stdata[numerical_column] >= lower_bound) & (stdata[numerical_column] <= upper_bound)]

# Now, df_no_outliers contains your data with outliers removed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data into a pandas DataFrame (replace 'data.csv' with your file)
# df = pd.read_csv('data.csv')

# Specify the column containing the numerical data you want to analyze (e.g., "Profit")
numerical_column = "Profit"

# Create a box plot to visualize the data distribution before removing outliers
plt.figure(figsize=(8, 4))
sns.boxplot(data=stdata, y=numerical_column)
plt.title("Box Plot - Before Removing Outliers")
plt.show()

# Calculate the interquartile range (IQR)
Q1 = stdata[numerical_column].quantile(0.25)
Q3 = stdata[numerical_column].quantile(0.75)
IQR = Q3 - Q1

# Define the upper and lower bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_no_outliers = stdata[(stdata[numerical_column] >= lower_bound) & (stdata[numerical_column] <= upper_bound)]

# Create a box plot to visualize the data distribution after removing outliers
plt.figure(figsize=(8, 4))
sns.boxplot(data=df_no_outliers, y=numerical_column)
plt.title("Box Plot - After Removing Outliers")
plt.show()

# %%
import pandas as pd

# Assuming you have your data in a DataFrame called 'df'
# Replace 'df' with the actual name of your DataFrame if different

# Group by 'Category' and calculate the sum of profits
category_profit = stdata.groupby('Category')['Profit'].sum().reset_index()

# Sort the results in descending order to find the category with the highest profit
category_profit_sorted = category_profit.sort_values(by='Profit', ascending=False)

# Find the category with the highest profit
highest_profit_category = category_profit_sorted.iloc[0]

# Find the category with the lowest profit
lowest_profit_category = category_profit_sorted.iloc[-1]

print("Category with the Highest Profit:")
print(highest_profit_category)

print("\nCategory with the Lowest Profit:")
print(lowest_profit_category)
# Out:
# Category with the Highest Profit:
# Category     Technology
# Profit      145454.9481
# Name: 2, dtype: object
#
# Category with the Lowest Profit:
# Category     Furniture
# Profit      18421.8137
# Name: 0, dtype: object

# %%
import pandas as pd

# Assuming you have your data in a DataFrame called 'df'
# Replace 'df' with the actual name of your DataFrame if different

# Group by 'Category' and calculate the sum of profits
category_profit = stdata.groupby('Sub-Category')['Profit'].sum().reset_index()

# Sort the results in descending order to find the category with the highest profit
category_profit_sorted = category_profit.sort_values(by='Profit', ascending=False)

# Find the category with the highest profit
highest_profit_category = category_profit_sorted.iloc[0]

# Find the category with the lowest profit
lowest_profit_category = category_profit_sorted.iloc[-1]

print("SubCategory with the Highest Profit:")
print(highest_profit_category)

print("\nSubCategory with the Lowest Profit:")
print(lowest_profit_category)
# Out:
# SubCategory with the Highest Profit:
# Sub-Category       Copiers
# Profit          55617.8249
# Name: 6, dtype: object
#
# SubCategory with the Lowest Profit:
# Sub-Category        Tables
# Profit         -17725.4811
# Name: 16, dtype: object

# %%
import pandas as pd

# Assuming you have your data in a DataFrame called 'df'
# Replace 'df' with the actual name of your DataFrame if different

# Group by 'Category' and calculate the sum of profits
category_profit = stdata.groupby('City')['Profit'].sum().reset_index()

# Sort the results in descending order to find the category with the highest profit
category_profit_sorted = category_profit.sort_values(by='Profit', ascending=False)

# Find the category with the highest profit
highest_profit_category = category_profit_sorted.iloc[0]

# Find the category with the lowest profit
lowest_profit_category = category_profit_sorted.iloc[-1]

print("City with the Highest Profit:")
print(highest_profit_category)

print("\City with the Lowest Profit:")
print(lowest_profit_category)
# Out:
# City with the Highest Profit:
# City      New York City
# Profit       62013.8973
# Name: 329, dtype: object
# \City with the Lowest Profit:
# City      Philadelphia
# Profit     -13843.2106
# Name: 374, dtype: object

# %%
import pandas as pd

# Assuming you already have a DataFrame df with your data loaded

# Group the DataFrame by the 'Category' column and calculate the mean discount for each category
category_discount = stdata.groupby('Category')['Discount'].mean().reset_index()

# Find the category with the highest discount
highest_discount_category = category_discount[category_discount['Discount'] == category_discount['Discount'].max()]

# Find the category with the lowest discount
lowest_discount_category = category_discount[category_discount['Discount'] == category_discount['Discount'].min()]

print("Category with the highest discount:")
print(highest_discount_category)

print("\nCategory with the lowest discount:")
print(lowest_discount_category)
# Out:
# Category with the highest discount:
#     Category  Discount
# 0  Furniture  0.174027
#
# Category with the lowest discount:
#      Category  Discount
# 2  Technology  0.132323

# %%
import pandas as pd

# Assuming you already have a DataFrame df with your data loaded

# Group the DataFrame by 'Segment' and calculate the total profit and loss for each segment
segment_profit_loss = stdata.groupby('Segment')['Profit'].sum().reset_index()

# Display the profit and loss by segment
print(segment_profit_loss)
# Out:
#        Segment       Profit
# 0     Consumer  134007.4413
# 1    Corporate   91954.9798
# 2  Home Office   60279.0015

# %%
import pandas as pd

# Assuming you already have a DataFrame df with your data loaded

# Group the DataFrame by 'Segment' and calculate the total profit and loss for each segment
segment_profit_loss = stdata.groupby('Segment')['Profit'].sum().reset_index()

# Find the segment with the highest profit
highest_profit_segment = segment_profit_loss[segment_profit_loss['Profit'] == segment_profit_loss['Profit'].max()]

# Find the segment with the highest loss
highest_loss_segment = segment_profit_loss[segment_profit_loss['Profit'] == segment_profit_loss['Profit'].min()]

# Display the segments with the highest profit and highest loss
print("Segment with the Highest Profit:")
print(highest_profit_segment)

print("\nSegment with the Highest Loss:")
print(highest_loss_segment)
# Out:
# Segment with the Highest Profit:
#     Segment       Profit
# 0  Consumer  134007.4413
#
# Segment with the Highest Loss:
#        Segment      Profit
# 2  Home Office  60279.0015

# %%
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame df with your data loaded

# Group the DataFrame by 'Segment' and calculate the total profit and loss for each segment
segment_profit_loss = stdata.groupby('Segment')['Profit'].sum().reset_index()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(segment_profit_loss['Segment'], segment_profit_loss['Profit'])
plt.xlabel('Segment')
plt.ylabel('Profit/Loss')
plt.title('Profit and Loss by Segment')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(segment_profit_loss['Profit'], labels=segment_profit_loss['Segment'], autopct='%1.1f%%', startangle=140)
plt.title('Profit and Loss Distribution by Segment')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame df with your data loaded

# Calculate the correlation matrix
correlation_matrix = stdata.corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df with your data loaded

# Create a simple line chart using a numerical index as the x-axis
plt.figure(figsize=(10, 6))
plt.plot(stdata.index, stdata['Profit'], marker='o', linestyle='-', color='b', label='Profit')
plt.xlabel('Index')
plt.ylabel('Profit')
plt.title('Line Chart Example')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df with your data loaded

# Scatter plot: X-axis represents one variable, and Y-axis represents another variable
plt.figure(figsize=(8, 6))
plt.scatter(stdata['Sales'], stdata['Profit'], c='blue', alpha=0.5)  # Replace 'Variable1' and 'Variable2' with your column names
plt.xlabel('Sales Label')
plt.ylabel('Profit Label')
plt.title('Scatter Plot ')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df with your data loaded

# Create a violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='Category', y='Profit', data=stdata, palette='muted')  # Replace 'Category' and 'Value' with your column names
plt.xlabel('Category')
plt.ylabel('Profit')
plt.title('Violin Plot')
plt.xticks(rotation=45)  # Rotate category labels if needed
plt.grid(True)
plt.show()

# %%
#use label encoder to handle categorical data
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
stdata["Segment"]=LE.fit_transform(stdata[["Segment"]])

# %%
#use label encoder to handle categorical data
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
stdata["City"]=LE.fit_transform(stdata[["City"]])

# %%
#use label encoder to handle categorical data
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
stdata["Category"]=LE.fit_transform(stdata[["Category"]])

# %%
#use label encoder to handle categorical data
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
stdata["Sub-Category"]=LE.fit_transform(stdata[["Sub-Category"]])

# %%
stdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9977 entries, 0 to 9976
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Segment       9977 non-null   int32
#  1   City          9977 non-null   int32
#  2   Category      9977 non-null   int32
#  3   Sub-Category  9977 non-null   int32
#  4   Sales         9977 non-null   float64
#  5   Quantity      9977 non-null   int64
#  6   Discount      9977 non-null   float64
#  7   Profit        9977 non-null   float64
# dtypes: float64(3), int32(4), int64(1)
# memory usage: 467.8 KB

# %%
stdata.head()
# Out:
#    Segment  City  Category  Sub-Category     Sales  Quantity  Discount  \
# 0        0   194         0             4  261.9600         2      0.00
# 1        0   194         0             5  731.9400         3      0.00
# 2        1   266         1            10   14.6200         2      0.00
# 3        0   153         0            16  957.5775         5      0.45
# 4        0   153         1            14   22.3680         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
import pandas as pd

# Load your data into a pandas DataFrame (replace 'data.csv' with your file)
# df = pd.read_csv('data.csv')

# Calculate the mean of the "Sales Amount ($)" column
profit_amount_mean = stdata['Profit'].mean()
profit_total=stdata["Profit"].sum()
# Calculate the mean of the "Sales Amount ($)" column
sales_amount_mean = stdata['Sales'].mean()
sales_total=stdata["Sales"].sum()

# Print the mean value
print("Mean profit Amount: ${:.2f}".format(profit_amount_mean))
print("total profit Amount: ${:.2f}".format(profit_total))
# Print the mean value
print("Mean sales Amount: ${:.2f}".format(sales_amount_mean))
print("total sales Amount: ${:.2f}".format(sales_total))
# Out:
# Mean profit Amount: $28.69
# total profit Amount: $286241.42
# Mean sales Amount: $230.15
# total sales Amount: $2296195.59

# %%
#Identify the independent and Target (dependent) variable
IndepVar = []
for col in stdata.columns:
    if col != 'Profit':
        IndepVar.append(col)

TargetVar = 'Profit'
x = stdata[IndepVar]
y = stdata[TargetVar]

# %%
# Split the data into train and test (random sampling)

from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=28)

# Display the shape for train & test data

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((6983, 7), (2994, 7), (6983,), (2994,))

# %%
 #Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

#x_train[cols]= mmscaler.fit_transform(x_train[cols])
x_train= mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

#x_test[cols]= mmscaler.fit_transform(x_test[cols])
x_test = mmscaler.fit_transform(x_test)

x_test = pd.DataFrame(x_test)

# %%
#multiple regression
# Build the multi regression model

from sklearn.linear_model import LinearRegression  

# Create object for the model

ModelMLR = LinearRegression()

# Train the model with training data

ModelMLR.fit(x_train, y_train)

# Predict the model with test dataset

y_pred = ModelMLR.predict(x_test)

# Evaluation metrics for Regression analysis

from sklearn import metrics
#print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
#print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
#print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
#print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
#print('Mean Absolute Percentage Error (MAPE):', round(metrics.mean_absolute_percentage_error(y_test, y_pred)*100,3), '%')
# Define the function to calculate the MAPE - Mean Absolute Percentage Error

def MAPE (y_test, y_pred): 
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# Evaluation of MAPE
#result = MAPE(y_test, y_pred)
#print('Mean Absolute Percentage Error (MAPE):', round(result, 3), '%')

# Calculate Adjusted R squared values 

r_squared = round(metrics.r2_score(y_test, y_pred),6)
adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
print('Adj R Square: ', adjusted_r_squared)
# Out:
# R2_score: 0.576054
# Adj R Square:  0.575756

# %%
#compare classification algorithms
#load the results
RGRResults=pd.read_csv(r"C:\Users\R Sobha Supriya\Desktop\internship datsets&files\RGRResults.csv",header=0)
#display first 5 records
RGRResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
# Build the Regression / Regressor models

from sklearn.linear_model import LinearRegression
#from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.linear_model import BayesianRidge
#from sklearn.svm import SVR

# Create objects of Regression / Regressor models with default hyper-parameters

ModelMLR = LinearRegression()
#ModelDCR = DecisionTreeRegressor()
ModelRFR = RandomForestRegressor()
ModelETR = ExtraTreesRegressor()
#ModelKNN = KNeighborsRegressor(n_neighbors=5)
#ModelBRR = BayesianRidge()
#ModelSVR = SVR()

# Evalution matrix for all the algorithms

#MM = [ModelMLR, ModelDCR, ModelRFR, ModelETR, ModelKNN, ModelBRR, ModelSVR] 
MM = [ModelMLR, ModelRFR, ModelETR]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(x_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    #print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    #print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    #print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
   # print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    #print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    RGRResults = RGRResults.append(new_row, ignore_index=True)
    #-------------------------------------------------------------------------------------------
# Out:
# Model Name:  LinearRegression()
# R2_score: 0.576054
# Adj R Square:  0.575756
# ------------------------------------------------------------------------------------------------------------
# Model Name:  RandomForestRegressor()
# R2_score: 0.53577
# Adj R Square:  0.535444
# ------------------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesRegressor()
# R2_score: 0.66398
# Adj R Square:  0.663744
# ------------------------------------------------------------------------------------------------------------
